# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 6))
plt.hexbin(df['University_GPA'], df['Soft_Skills_Score'], gridsize=25, cmap='Purples')
plt.colorbar(label='Count')
plt.xlabel('University GPA')
plt.ylabel('Soft Skills Score')
plt.title('Density of GPA vs Soft Skills')
plt.tight_layout()
plt.show()
